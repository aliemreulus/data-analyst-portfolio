# %% [markdown]
# # Exploratory Data Analysis
# *Auto-generated – 2026-07-06*

# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)
n = 500
df = pd.DataFrame({
    'age':        np.random.randint(18, 65, n),
    'salary':     np.random.normal(55000, 15000, n).round(2),
    'experience': np.random.randint(0, 40, n),
    'department': np.random.choice(['Engineering','Marketing','Sales','HR','Finance'], n),
    'score':      np.random.uniform(1, 10, n).round(1),
})
print(df.shape)
df.head()

# %%
df.describe()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
sns.histplot(df['salary'], bins=30, ax=axes[0], color='steelblue')
axes[0].set_title('Salary Distribution')
sns.boxplot(data=df, x='department', y='salary', ax=axes[1])
axes[1].set_title('Salary by Department')
plt.xticks(rotation=30)
plt.tight_layout()
plt.savefig('notebooks/eda_plot_2026-07-06.png', dpi=80, bbox_inches='tight')
plt.show()

# %%
print(df.groupby('department')['salary'].agg(['mean','median','count']).round(2))
